# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-qry6oekc because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
x = np.linspace(-20, 20, 80)

# %%
y = 2 ** (-x)

# %%
y
# Out:
# array([1.04857600e+06, 7.38209555e+05, 5.19708011e+05, 3.65880413e+05,
#        2.57584016e+05, 1.81342107e+05, 1.27666928e+05, 8.98789844e+04,
#        6.32758380e+04, 4.45469172e+04, 3.13615417e+04, 2.20788858e+04,
#        1.55437893e+04, 1.09430063e+04, 7.70400223e+03, 5.42370611e+03,
#        3.81835144e+03, 2.68816329e+03, 1.89249785e+03, 1.33234024e+03,
#        9.37982841e+02, 6.60350701e+02, 4.64894483e+02, 3.27291059e+02,
#        2.30416667e+02, 1.62215982e+02, 1.14201915e+02, 8.03994610e+01,
#        5.66021446e+01, 3.98485603e+01, 2.80538444e+01, 1.97502289e+01,
#        1.39043881e+01, 9.78884905e+00, 6.89146223e+00, 4.85166861e+00,
#        3.41563046e+00, 2.40464310e+00, 1.69289638e+00, 1.19181851e+00,
#        8.39053927e-01, 5.90703608e-01, 4.15862129e-01, 2.92771718e-01,
#        2.06114654e-01, 1.45107086e-01, 1.02157056e-01, 7.19197415e-02,
#        5.06323246e-02, 3.56457384e-02, 2.50950095e-02, 1.76671751e-02,
# ...

# %%
plt.plot(x,y)

# %%
s = 1 / (1 + y)

# %%
plt.plot(x, s)
